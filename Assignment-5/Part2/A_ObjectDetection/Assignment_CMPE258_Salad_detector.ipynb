# %% [markdown]
# Install required packages

# %%
# !pip install -q tflite-model-maker
# !pip install -q pycocotools
# !pip install -q tflite-support
# Out:
#      |████████████████████████████████| 616 kB 8.7 MB/s
#      |████████████████████████████████| 596 kB 45.7 MB/s
#      |████████████████████████████████| 237 kB 46.8 MB/s
#      |████████████████████████████████| 1.1 MB 14.8 MB/s
#      |████████████████████████████████| 87 kB 3.2 MB/s
#      |████████████████████████████████| 840 kB 59.7 MB/s
#      |████████████████████████████████| 1.1 MB 50.3 MB/s
#      |████████████████████████████████| 77 kB 5.6 MB/s
#      |████████████████████████████████| 6.4 MB 33.6 MB/s
#      |████████████████████████████████| 1.2 MB 42.5 MB/s
#      |████████████████████████████████| 120 kB 18.8 MB/s
#      |████████████████████████████████| 3.4 MB 32.7 MB/s
#      |████████████████████████████████| 25.3 MB 1.5 MB/s
#      |████████████████████████████████| 47.8 MB 42 kB/s
#      |████████████████████████████████| 352 kB 46.8 MB/s
#      |████████████████████████████████| 99 kB 8.3 MB/s
#      |████████████████████████████████| 462 kB 51.7 MB/s
#      |████████████████████████████████| 213 kB 53.1 MB/s
#   Building wheel for fire (setup.py) ... done
#   Building wheel for py-cpuinfo (setup.py) ... done

# %% [markdown]
# import libraries

# %%
import numpy as np
import os

from tflite_model_maker.config import ExportFormat
from tflite_model_maker import model_spec
from tflite_model_maker import object_detector

import tensorflow as tf
assert tf.__version__.startswith('2')

tf.get_logger().setLevel('ERROR')
from absl import logging
logging.set_verbosity(logging.ERROR)

# %% [markdown]
# download data

# %%
train_data, validation_data, test_data = object_detector.DataLoader.from_csv('gs://cloud-ml-data/img/openimage/csv/salads_ml_use.csv')

# %%
spec = model_spec.get('efficientdet_lite2')

# %% [markdown]
# train the tensorflow model with training data

# %%
model = object_detector.create(train_data, model_spec=spec, batch_size=8, train_whole_model=True, validation_data=validation_data)
# Out:
# Epoch 1/50
# 21/21 [==============================] - 332s 13s/step - det_loss: 1.7435 - cls_loss: 1.1418 - box_loss: 0.0120 - reg_l2_loss: 0.0764 - loss: 1.8199 - learning_rate: 0.0090 - gradient_norm: 0.7254 - val_det_loss: 1.6587 - val_cls_loss: 1.1087 - val_box_loss: 0.0110 - val_reg_l2_loss: 0.0764 - val_loss: 1.7351
# Epoch 2/50
# 21/21 [==============================] - 269s 13s/step - det_loss: 1.6095 - cls_loss: 1.0983 - box_loss: 0.0102 - reg_l2_loss: 0.0764 - loss: 1.6859 - learning_rate: 0.0100 - gradient_norm: 1.0223 - val_det_loss: 1.5311 - val_cls_loss: 1.0167 - val_box_loss: 0.0103 - val_reg_l2_loss: 0.0764 - val_loss: 1.6075
# Epoch 3/50
# 21/21 [==============================] - 261s 12s/step - det_loss: 1.4137 - cls_loss: 0.9778 - box_loss: 0.0087 - reg_l2_loss: 0.0764 - loss: 1.4901 - learning_rate: 0.0099 - gradient_norm: 1.8575 - val_det_loss: 1.3844 - val_cls_loss: 0.9040 - val_box_loss: 0.0096 - val_reg_l2_loss: 0.0764 - val_loss: 1.4609
# Epoch 4/50
# 21/21 [==============================] - 259s 12s/step - det_loss: 1.1842 - cls_loss: 0.8057 - box_loss: 0.0076 - reg_l2_loss: 0.0764 - loss: 1.2606 - learning_rate: 0.0099 - gradient_norm: 2.0761 - val_det_loss: 1.1848 - val_cls_loss: 0.7462 - val_box_loss: 0.0088 - val_reg_l2_loss: 0.0764 - val_loss: 1.2612
# Epoch 5/50
# 21/21 [==============================] - 282s 14s/step - det_loss: 1.0664 - cls_loss: 0.7273 - box_loss: 0.0068 - reg_l2_loss: 0.0764 - loss: 1.1429 - learning_rate: 0.0098 - gradient_norm: 2.1931 - val_det_loss: 1.1667 - val_cls_loss: 0.7450 - val_box_loss: 0.0084 - val_reg_l2_loss: 0.0765 - val_loss: 1.2432
# Epoch 6/50
# 21/21 [==============================] - 264s 13s/step - det_loss: 0.9995 - cls_loss: 0.6807 - box_loss: 0.0064 - reg_l2_loss: 0.0765 - loss: 1.0760 - learning_rate: 0.0097 - gradient_norm: 2.2487 - val_det_loss: 1.1070 - val_cls_loss: 0.6776 - val_box_loss: 0.0086 - val_reg_l2_loss: 0.0765 - val_loss: 1.1835
# Epoch 7/50
# 21/21 [==============================] - 264s 13s/step - det_loss: 0.9353 - cls_loss: 0.6416 - box_loss: 0.0059 - reg_l2_loss: 0.0765 - loss: 1.0118 - learning_rate: 0.0096 - gradient_norm: 2.2717 - val_det_loss: 1.0373 - val_cls_loss: 0.6432 - val_box_loss: 0.0079 - val_reg_l2_loss: 0.0765 - val_loss: 1.1138
# Epoch 8/50
# 21/21 [==============================] - 270s 13s/step - det_loss: 0.9063 - cls_loss: 0.6213 - box_loss: 0.0057 - reg_l2_loss: 0.0765 - loss: 0.9828 - learning_rate: 0.0094 - gradient_norm: 2.4129 - val_det_loss: 0.9781 - val_cls_loss: 0.5985 - val_box_loss: 0.0076 - val_reg_l2_loss: 0.0765 - val_loss: 1.0546
# Epoch 9/50
# 21/21 [==============================] - 266s 13s/step - det_loss: 0.8801 - cls_loss: 0.6065 - box_loss: 0.0055 - reg_l2_loss: 0.0765 - loss: 0.9566 - learning_rate: 0.0093 - gradient_norm: 2.3641 - val_det_loss: 0.9591 - val_cls_loss: 0.5965 - val_box_loss: 0.0073 - val_reg_l2_loss: 0.0765 - val_loss: 1.0356
# Epoch 10/50
# 21/21 [==============================] - 283s 14s/step - det_loss: 0.8484 - cls_loss: 0.5811 - box_loss: 0.0053 - reg_l2_loss: 0.0765 - loss: 0.9249 - learning_rate: 0.0091 - gradient_norm: 2.2392 - val_det_loss: 0.9586 - val_cls_loss: 0.6022 - val_box_loss: 0.0071 - val_reg_l2_loss: 0.0765 - val_loss: 1.0352
# Epoch 11/50
# 21/21 [==============================] - 268s 13s/step - det_loss: 0.8050 - cls_loss: 0.5452 - box_loss: 0.0052 - reg_l2_loss: 0.0765 - loss: 0.8816 - learning_rate: 0.0089 - gradient_norm: 2.2624 - val_det_loss: 0.9202 - val_cls_loss: 0.5902 - val_box_loss: 0.0066 - val_reg_l2_loss: 0.0765 - val_loss: 0.9967
# Epoch 12/50
# 21/21 [==============================] - 270s 13s/step - det_loss: 0.7975 - cls_loss: 0.5431 - box_loss: 0.0051 - reg_l2_loss: 0.0765 - loss: 0.8740 - learning_rate: 0.0087 - gradient_norm: 2.7787 - val_det_loss: 0.9178 - val_cls_loss: 0.5900 - val_box_loss: 0.0066 - val_reg_l2_loss: 0.0765 - val_loss: 0.9943
# Epoch 13/50
# 21/21 [==============================] - 263s 13s/step - det_loss: 0.8041 - cls_loss: 0.5412 - box_loss: 0.0053 - reg_l2_loss: 0.0766 - loss: 0.8807 - learning_rate: 0.0085 - gradient_norm: 3.0154 - val_det_loss: 1.0270 - val_cls_loss: 0.6818 - val_box_loss: 0.0069 - val_reg_l2_loss: 0.0766 - val_loss: 1.1035
# Epoch 14/50
# 21/21 [==============================] - 266s 13s/step - det_loss: 0.7688 - cls_loss: 0.5129 - box_loss: 0.0051 - reg_l2_loss: 0.0766 - loss: 0.8453 - learning_rate: 0.0082 - gradient_norm: 2.5662 - val_det_loss: 0.9510 - val_cls_loss: 0.5992 - val_box_loss: 0.0070 - val_reg_l2_loss: 0.0766 - val_loss: 1.0276
# Epoch 15/50
# 21/21 [==============================] - 282s 13s/step - det_loss: 0.7452 - cls_loss: 0.5103 - box_loss: 0.0047 - reg_l2_loss: 0.0766 - loss: 0.8218 - learning_rate: 0.0080 - gradient_norm: 2.6390 - val_det_loss: 0.9488 - val_cls_loss: 0.6224 - val_box_loss: 0.0065 - val_reg_l2_loss: 0.0766 - val_loss: 1.0254
# Epoch 16/50
# 21/21 [==============================] - 268s 13s/step - det_loss: 0.7152 - cls_loss: 0.4983 - box_loss: 0.0043 - reg_l2_loss: 0.0766 - loss: 0.7918 - learning_rate: 0.0077 - gradient_norm: 2.6309 - val_det_loss: 0.8553 - val_cls_loss: 0.5458 - val_box_loss: 0.0062 - val_reg_l2_loss: 0.0766 - val_loss: 0.9319
# Epoch 17/50
# 21/21 [==============================] - 267s 13s/step - det_loss: 0.7172 - cls_loss: 0.4940 - box_loss: 0.0045 - reg_l2_loss: 0.0766 - loss: 0.7938 - learning_rate: 0.0075 - gradient_norm: 2.6969 - val_det_loss: 0.8519 - val_cls_loss: 0.5438 - val_box_loss: 0.0062 - val_reg_l2_loss: 0.0766 - val_loss: 0.9285
# Epoch 18/50
# 21/21 [==============================] - 265s 13s/step - det_loss: 0.7345 - cls_loss: 0.4991 - box_loss: 0.0047 - reg_l2_loss: 0.0766 - loss: 0.8111 - learning_rate: 0.0072 - gradient_norm: 3.0408 - val_det_loss: 0.9330 - val_cls_loss: 0.6322 - val_box_loss: 0.0060 - val_reg_l2_loss: 0.0766 - val_loss: 1.0096
# Epoch 19/50
# 21/21 [==============================] - 268s 13s/step - det_loss: 0.7025 - cls_loss: 0.4819 - box_loss: 0.0044 - reg_l2_loss: 0.0766 - loss: 0.7792 - learning_rate: 0.0069 - gradient_norm: 2.8958 - val_det_loss: 0.9144 - val_cls_loss: 0.6089 - val_box_loss: 0.0061 - val_reg_l2_loss: 0.0766 - val_loss: 0.9910
# Epoch 20/50
# 21/21 [==============================] - 276s 13s/step - det_loss: 0.6927 - cls_loss: 0.4733 - box_loss: 0.0044 - reg_l2_loss: 0.0766 - loss: 0.7694 - learning_rate: 0.0066 - gradient_norm: 2.8057 - val_det_loss: 0.8678 - val_cls_loss: 0.5671 - val_box_loss: 0.0060 - val_reg_l2_loss: 0.0766 - val_loss: 0.9445
# Epoch 21/50
# 21/21 [==============================] - 267s 13s/step - det_loss: 0.6820 - cls_loss: 0.4606 - box_loss: 0.0044 - reg_l2_loss: 0.0767 - loss: 0.7587 - learning_rate: 0.0063 - gradient_norm: 2.7163 - val_det_loss: 0.8444 - val_cls_loss: 0.5455 - val_box_loss: 0.0060 - val_reg_l2_loss: 0.0767 - val_loss: 0.9211
# Epoch 22/50
# 21/21 [==============================] - 272s 13s/step - det_loss: 0.6481 - cls_loss: 0.4532 - box_loss: 0.0039 - reg_l2_loss: 0.0767 - loss: 0.7248 - learning_rate: 0.0060 - gradient_norm: 2.6707 - val_det_loss: 0.8807 - val_cls_loss: 0.5741 - val_box_loss: 0.0061 - val_reg_l2_loss: 0.0767 - val_loss: 0.9573
# Epoch 23/50
# 21/21 [==============================] - 266s 13s/step - det_loss: 0.6700 - cls_loss: 0.4543 - box_loss: 0.0043 - reg_l2_loss: 0.0767 - loss: 0.7466 - learning_rate: 0.0056 - gradient_norm: 2.8079 - val_det_loss: 0.8697 - val_cls_loss: 0.5595 - val_box_loss: 0.0062 - val_reg_l2_loss: 0.0767 - val_loss: 0.9464
# Epoch 24/50
# 21/21 [==============================] - 271s 13s/step - det_loss: 0.6623 - cls_loss: 0.4527 - box_loss: 0.0042 - reg_l2_loss: 0.0767 - loss: 0.7389 - learning_rate: 0.0053 - gradient_norm: 2.5678 - val_det_loss: 0.8499 - val_cls_loss: 0.5423 - val_box_loss: 0.0062 - val_reg_l2_loss: 0.0767 - val_loss: 0.9266
# Epoch 25/50
# 21/21 [==============================] - 274s 13s/step - det_loss: 0.6681 - cls_loss: 0.4455 - box_loss: 0.0045 - reg_l2_loss: 0.0767 - loss: 0.7448 - learning_rate: 0.0050 - gradient_norm: 2.8128 - val_det_loss: 0.8161 - val_cls_loss: 0.5262 - val_box_loss: 0.0058 - val_reg_l2_loss: 0.0767 - val_loss: 0.8928
# Epoch 26/50
# 21/21 [==============================] - 261s 13s/step - det_loss: 0.6313 - cls_loss: 0.4322 - box_loss: 0.0040 - reg_l2_loss: 0.0767 - loss: 0.7080 - learning_rate: 0.0047 - gradient_norm: 2.8180 - val_det_loss: 0.8092 - val_cls_loss: 0.5243 - val_box_loss: 0.0057 - val_reg_l2_loss: 0.0767 - val_loss: 0.8859
# Epoch 27/50
# 21/21 [==============================] - 270s 13s/step - det_loss: 0.6205 - cls_loss: 0.4248 - box_loss: 0.0039 - reg_l2_loss: 0.0767 - loss: 0.6972 - learning_rate: 0.0044 - gradient_norm: 2.8012 - val_det_loss: 0.8422 - val_cls_loss: 0.5509 - val_box_loss: 0.0058 - val_reg_l2_loss: 0.0767 - val_loss: 0.9189
# Epoch 28/50
# 21/21 [==============================] - 266s 13s/step - det_loss: 0.5903 - cls_loss: 0.4114 - box_loss: 0.0036 - reg_l2_loss: 0.0767 - loss: 0.6670 - learning_rate: 0.0040 - gradient_norm: 2.4509 - val_det_loss: 0.8691 - val_cls_loss: 0.5771 - val_box_loss: 0.0058 - val_reg_l2_loss: 0.0767 - val_loss: 0.9458
# Epoch 29/50
# 21/21 [==============================] - 269s 13s/step - det_loss: 0.5973 - cls_loss: 0.4132 - box_loss: 0.0037 - reg_l2_loss: 0.0767 - loss: 0.6739 - learning_rate: 0.0037 - gradient_norm: 2.5942 - val_det_loss: 0.8389 - val_cls_loss: 0.5353 - val_box_loss: 0.0061 - val_reg_l2_loss: 0.0767 - val_loss: 0.9156
# Epoch 30/50
# 21/21 [==============================] - 291s 14s/step - det_loss: 0.6352 - cls_loss: 0.4332 - box_loss: 0.0040 - reg_l2_loss: 0.0767 - loss: 0.7118 - learning_rate: 0.0034 - gradient_norm: 2.9358 - val_det_loss: 0.8291 - val_cls_loss: 0.5347 - val_box_loss: 0.0059 - val_reg_l2_loss: 0.0767 - val_loss: 0.9058
# Epoch 31/50
# 21/21 [==============================] - 268s 13s/step - det_loss: 0.6238 - cls_loss: 0.4201 - box_loss: 0.0041 - reg_l2_loss: 0.0767 - loss: 0.7005 - learning_rate: 0.0031 - gradient_norm: 2.9031 - val_det_loss: 0.8372 - val_cls_loss: 0.5501 - val_box_loss: 0.0057 - val_reg_l2_loss: 0.0767 - val_loss: 0.9139
# Epoch 32/50
# 21/21 [==============================] - 268s 13s/step - det_loss: 0.5682 - cls_loss: 0.3862 - box_loss: 0.0036 - reg_l2_loss: 0.0767 - loss: 0.6449 - learning_rate: 0.0028 - gradient_norm: 2.5147 - val_det_loss: 0.8167 - val_cls_loss: 0.5319 - val_box_loss: 0.0057 - val_reg_l2_loss: 0.0767 - val_loss: 0.8934
# Epoch 33/50
# 21/21 [==============================] - 266s 13s/step - det_loss: 0.5837 - cls_loss: 0.3985 - box_loss: 0.0037 - reg_l2_loss: 0.0767 - loss: 0.6604 - learning_rate: 0.0025 - gradient_norm: 2.6919 - val_det_loss: 0.8188 - val_cls_loss: 0.5310 - val_box_loss: 0.0058 - val_reg_l2_loss: 0.0767 - val_loss: 0.8955
# Epoch 34/50
# 21/21 [==============================] - 273s 13s/step - det_loss: 0.5803 - cls_loss: 0.3930 - box_loss: 0.0037 - reg_l2_loss: 0.0767 - loss: 0.6569 - learning_rate: 0.0023 - gradient_norm: 2.6021 - val_det_loss: 0.8523 - val_cls_loss: 0.5586 - val_box_loss: 0.0059 - val_reg_l2_loss: 0.0767 - val_loss: 0.9290
# Epoch 35/50
# 21/21 [==============================] - 282s 14s/step - det_loss: 0.5856 - cls_loss: 0.4003 - box_loss: 0.0037 - reg_l2_loss: 0.0767 - loss: 0.6623 - learning_rate: 0.0020 - gradient_norm: 2.9659 - val_det_loss: 0.8268 - val_cls_loss: 0.5406 - val_box_loss: 0.0057 - val_reg_l2_loss: 0.0767 - val_loss: 0.9035
# Epoch 36/50
# 21/21 [==============================] - 276s 13s/step - det_loss: 0.5738 - cls_loss: 0.3960 - box_loss: 0.0036 - reg_l2_loss: 0.0767 - loss: 0.6504 - learning_rate: 0.0018 - gradient_norm: 2.7481 - val_det_loss: 0.8238 - val_cls_loss: 0.5378 - val_box_loss: 0.0057 - val_reg_l2_loss: 0.0767 - val_loss: 0.9005
# Epoch 37/50
# 21/21 [==============================] - 270s 13s/step - det_loss: 0.5878 - cls_loss: 0.4012 - box_loss: 0.0037 - reg_l2_loss: 0.0767 - loss: 0.6645 - learning_rate: 0.0015 - gradient_norm: 2.7938 - val_det_loss: 0.8307 - val_cls_loss: 0.5444 - val_box_loss: 0.0057 - val_reg_l2_loss: 0.0767 - val_loss: 0.9074
# Epoch 38/50
# 21/21 [==============================] - 277s 13s/step - det_loss: 0.5630 - cls_loss: 0.3829 - box_loss: 0.0036 - reg_l2_loss: 0.0767 - loss: 0.6397 - learning_rate: 0.0013 - gradient_norm: 2.6055 - val_det_loss: 0.8194 - val_cls_loss: 0.5374 - val_box_loss: 0.0056 - val_reg_l2_loss: 0.0767 - val_loss: 0.8960
# Epoch 39/50
# 21/21 [==============================] - 268s 13s/step - det_loss: 0.5447 - cls_loss: 0.3744 - box_loss: 0.0034 - reg_l2_loss: 0.0767 - loss: 0.6214 - learning_rate: 0.0011 - gradient_norm: 2.4767 - val_det_loss: 0.8108 - val_cls_loss: 0.5293 - val_box_loss: 0.0056 - val_reg_l2_loss: 0.0767 - val_loss: 0.8875
# Epoch 40/50
# 21/21 [==============================] - 278s 13s/step - det_loss: 0.5616 - cls_loss: 0.3859 - box_loss: 0.0035 - reg_l2_loss: 0.0767 - loss: 0.6383 - learning_rate: 9.0029e-04 - gradient_norm: 2.6828 - val_det_loss: 0.8316 - val_cls_loss: 0.5455 - val_box_loss: 0.0057 - val_reg_l2_loss: 0.0767 - val_loss: 0.9083
# Epoch 41/50
# 21/21 [==============================] - 268s 13s/step - det_loss: 0.5833 - cls_loss: 0.3943 - box_loss: 0.0038 - reg_l2_loss: 0.0767 - loss: 0.6600 - learning_rate: 7.2543e-04 - gradient_norm: 3.0947 - val_det_loss: 0.8470 - val_cls_loss: 0.5567 - val_box_loss: 0.0058 - val_reg_l2_loss: 0.0767 - val_loss: 0.9236
# Epoch 42/50
# 21/21 [==============================] - 271s 13s/step - det_loss: 0.5511 - cls_loss: 0.3765 - box_loss: 0.0035 - reg_l2_loss: 0.0767 - loss: 0.6278 - learning_rate: 5.6814e-04 - gradient_norm: 2.7705 - val_det_loss: 0.8417 - val_cls_loss: 0.5522 - val_box_loss: 0.0058 - val_reg_l2_loss: 0.0767 - val_loss: 0.9183
# Epoch 43/50
# 21/21 [==============================] - 266s 13s/step - det_loss: 0.5793 - cls_loss: 0.3954 - box_loss: 0.0037 - reg_l2_loss: 0.0767 - loss: 0.6560 - learning_rate: 4.2906e-04 - gradient_norm: 2.8702 - val_det_loss: 0.8466 - val_cls_loss: 0.5586 - val_box_loss: 0.0058 - val_reg_l2_loss: 0.0767 - val_loss: 0.9233
# Epoch 44/50
# 21/21 [==============================] - 274s 13s/step - det_loss: 0.5551 - cls_loss: 0.3764 - box_loss: 0.0036 - reg_l2_loss: 0.0767 - loss: 0.6318 - learning_rate: 3.0876e-04 - gradient_norm: 2.4531 - val_det_loss: 0.8456 - val_cls_loss: 0.5596 - val_box_loss: 0.0057 - val_reg_l2_loss: 0.0767 - val_loss: 0.9222
# Epoch 45/50
# 21/21 [==============================] - 279s 13s/step - det_loss: 0.5445 - cls_loss: 0.3756 - box_loss: 0.0034 - reg_l2_loss: 0.0767 - loss: 0.6212 - learning_rate: 2.0774e-04 - gradient_norm: 2.6542 - val_det_loss: 0.8407 - val_cls_loss: 0.5554 - val_box_loss: 0.0057 - val_reg_l2_loss: 0.0767 - val_loss: 0.9174
# Epoch 46/50
# 21/21 [==============================] - 272s 13s/step - det_loss: 0.5439 - cls_loss: 0.3693 - box_loss: 0.0035 - reg_l2_loss: 0.0767 - loss: 0.6206 - learning_rate: 1.2641e-04 - gradient_norm: 2.5924 - val_det_loss: 0.8371 - val_cls_loss: 0.5532 - val_box_loss: 0.0057 - val_reg_l2_loss: 0.0767 - val_loss: 0.9138
# Epoch 47/50
# 21/21 [==============================] - 270s 13s/step - det_loss: 0.5580 - cls_loss: 0.3811 - box_loss: 0.0035 - reg_l2_loss: 0.0767 - loss: 0.6347 - learning_rate: 6.5107e-05 - gradient_norm: 2.5176 - val_det_loss: 0.8374 - val_cls_loss: 0.5536 - val_box_loss: 0.0057 - val_reg_l2_loss: 0.0767 - val_loss: 0.9141
# Epoch 48/50
# 21/21 [==============================] - 271s 13s/step - det_loss: 0.5589 - cls_loss: 0.3831 - box_loss: 0.0035 - reg_l2_loss: 0.0767 - loss: 0.6356 - learning_rate: 2.4083e-05 - gradient_norm: 2.9390 - val_det_loss: 0.8349 - val_cls_loss: 0.5519 - val_box_loss: 0.0057 - val_reg_l2_loss: 0.0767 - val_loss: 0.9116
# Epoch 49/50
# 21/21 [==============================] - 273s 13s/step - det_loss: 0.5363 - cls_loss: 0.3689 - box_loss: 0.0033 - reg_l2_loss: 0.0767 - loss: 0.6130 - learning_rate: 3.5074e-06 - gradient_norm: 2.4631 - val_det_loss: 0.8339 - val_cls_loss: 0.5510 - val_box_loss: 0.0057 - val_reg_l2_loss: 0.0767 - val_loss: 0.9106
# Epoch 50/50
# 21/21 [==============================] - 278s 13s/step - det_loss: 0.5562 - cls_loss: 0.3802 - box_loss: 0.0035 - reg_l2_loss: 0.0767 - loss: 0.6328 - learning_rate: 3.4629e-06 - gradient_norm: 2.7008 - val_det_loss: 0.8350 - val_cls_loss: 0.5510 - val_box_loss: 0.0057 - val_reg_l2_loss: 0.0767 - val_loss: 0.9117

# %% [markdown]
# evaluate the model with test data

# %%
model.evaluate(test_data)
# Out:
# 1/1 [==============================] - 25s 25s/step
# {'AP': 0.20027716,
#  'AP50': 0.34035003,
#  'AP75': 0.21217363,
#  'AP_/Baked Goods': 0.011293505,
#  'AP_/Cheese': 0.15586475,
#  'AP_/Salad': 0.5475554,
#  'AP_/Seafood': 0.039531093,
#  'AP_/Tomato': 0.24714112,
#  'APl': 0.20046777,
#  'APm': 0.32928494,
#  'APs': -1.0,
#  'ARl': 0.35746515,
#  'ARm': 0.44166666,
#  'ARmax1': 0.17129791,
#  'ARmax10': 0.31776628,
#  'ARmax100': 0.35944408,
#  'ARs': -1.0}

# %% [markdown]
# export model

# %%
model.export(export_dir='.')

# %% [markdown]
# Test the TFlite model on image

# %%
 pip install opencv-python-headless==4.1.2.30

# %%
import platform
import json
import cv2
import tensorflow as tf
import numpy as np
from PIL import Image



from typing import List, NamedTuple
from tflite_support import metadata


Interpreter = tf.lite.Interpreter
load_delegate = tf.lite.experimental.load_delegate

# pylint: enable=g-import-not-at-top


class ObjectDetectorOptions(NamedTuple):
  """A config to initialize an object detector."""

  enable_edgetpu: bool = False
  """Enable the model to run on EdgeTPU."""

  label_allow_list: List[str] = None
  """The optional allow list of labels."""

  label_deny_list: List[str] = None
  """The optional deny list of labels."""

  max_results: int = -1
  """The maximum number of top-scored detection results to return."""

  num_threads: int = 1
  """The number of CPU threads to be used."""

  score_threshold: float = 0.0
  """The score threshold of detection results to return."""


class Rect(NamedTuple):
  """A rectangle in 2D space."""
  left: float
  top: float
  right: float
  bottom: float


class Category(NamedTuple):
  """A result of a classification task."""
  label: str
  score: float
  index: int


class Detection(NamedTuple):
  """A detected object as the result of an ObjectDetector."""
  bounding_box: Rect
  categories: List[Category]


def edgetpu_lib_name():
  """Returns the library name of EdgeTPU in the current platform."""
  return {
      'Darwin': 'libedgetpu.1.dylib',
      'Linux': 'libedgetpu.so.1',
      'Windows': 'edgetpu.dll',
  }.get(platform.system(), None)


class ObjectDetector:
  """A wrapper class for a TFLite object detection model."""

  _OUTPUT_LOCATION_NAME = 'location'
  _OUTPUT_CATEGORY_NAME = 'category'
  _OUTPUT_SCORE_NAME = 'score'
  _OUTPUT_NUMBER_NAME = 'number of detections'

  def __init__(
      self,
      model_path: str,
      options: ObjectDetectorOptions = ObjectDetectorOptions()
  ) -> None:
    """Initialize a TFLite object detection model.
    Args:
        model_path: Path to the TFLite model.
        options: The config to initialize an object detector. (Optional)
    Raises:
        ValueError: If the TFLite model is invalid.
        OSError: If the current OS isn't supported by EdgeTPU.
    """

    # Load metadata from model.
    displayer = metadata.MetadataDisplayer.with_model_file(model_path)

    # Save model metadata for preprocessing later.
    model_metadata = json.loads(displayer.get_metadata_json())
    process_units = model_metadata['subgraph_metadata'][0]['input_tensor_metadata'][0]['process_units']
    mean = 0.0
    std = 1.0
    for option in process_units:
      if option['options_type'] == 'NormalizationOptions':
        mean = option['options']['mean'][0]
        std = option['options']['std'][0]
    self._mean = mean
    self._std = std

    # Load label list from metadata.
    file_name = displayer.get_packed_associated_file_list()[0]
    label_map_file = displayer.get_associated_file_buffer(file_name).decode()
    label_list = list(filter(lambda x: len(x) > 0, label_map_file.splitlines()))
    self._label_list = label_list

    # Initialize TFLite model.
    if options.enable_edgetpu:
      if edgetpu_lib_name() is None:
        raise OSError("The current OS isn't supported by Coral EdgeTPU.")
      interpreter = Interpreter(
          model_path=model_path,
          experimental_delegates=[load_delegate(edgetpu_lib_name())],
          num_threads=options.num_threads)
    else:
      interpreter = Interpreter(
          model_path=model_path, num_threads=options.num_threads)

    interpreter.allocate_tensors()
    input_detail = interpreter.get_input_details()[0]

    # From TensorFlow 2.6, the order of the outputs become undefined.
    # Therefore we need to sort the tensor indices of TFLite outputs and to know
    # exactly the meaning of each output tensor. For example, if
    # output indices are [601, 599, 598, 600], tensor names and indices aligned
    # are:
    #   - location: 598
    #   - category: 599
    #   - score: 600
    #   - detection_count: 601
    # because of the op's ports of TFLITE_DETECTION_POST_PROCESS
    # (https://github.com/tensorflow/tensorflow/blob/a4fe268ea084e7d323133ed7b986e0ae259a2bc7/tensorflow/lite/kernels/detection_postprocess.cc#L47-L50).
    sorted_output_indices = sorted(
        [output['index'] for output in interpreter.get_output_details()])
    self._output_indices = {
        self._OUTPUT_LOCATION_NAME: sorted_output_indices[0],
        self._OUTPUT_CATEGORY_NAME: sorted_output_indices[1],
        self._OUTPUT_SCORE_NAME: sorted_output_indices[2],
        self._OUTPUT_NUMBER_NAME: sorted_output_indices[3],
    }

    self._input_size = input_detail['shape'][2], input_detail['shape'][1]
    self._is_quantized_input = input_detail['dtype'] == np.uint8
    self._interpreter = interpreter
    self._options = options

  def detect(self, input_image: np.ndarray) -> List[Detection]:
    """Run detection on an input image.
    Args:
        input_image: A [height, width, 3] RGB image. Note that height and width
          can be anything since the image will be immediately resized according
          to the needs of the model within this function.
    Returns:
        A Person instance.
    """
    image_height, image_width, _ = input_image.shape

    input_tensor = self._preprocess(input_image)

    self._set_input_tensor(input_tensor)
    self._interpreter.invoke()

    # Get all output details
    boxes = self._get_output_tensor(self._OUTPUT_LOCATION_NAME)
    classes = self._get_output_tensor(self._OUTPUT_CATEGORY_NAME)
    scores = self._get_output_tensor(self._OUTPUT_SCORE_NAME)
    count = int(self._get_output_tensor(self._OUTPUT_NUMBER_NAME))

    return self._postprocess(boxes, classes, scores, count, image_width,
                             image_height)

  def _preprocess(self, input_image: np.ndarray) -> np.ndarray:
    """Preprocess the input image as required by the TFLite model."""

    # Resize the input
    input_tensor = cv2.resize(input_image, self._input_size)

    # Normalize the input if it's a float model (aka. not quantized)
    if not self._is_quantized_input:
      input_tensor = (np.float32(input_tensor) - self._mean) / self._std

    # Add batch dimension
    input_tensor = np.expand_dims(input_tensor, axis=0)

    return input_tensor

  def _set_input_tensor(self, image):
    """Sets the input tensor."""
    tensor_index = self._interpreter.get_input_details()[0]['index']
    input_tensor = self._interpreter.tensor(tensor_index)()[0]
    input_tensor[:, :] = image

  def _get_output_tensor(self, name):
    """Returns the output tensor at the given index."""
    output_index = self._output_indices[name]
    tensor = np.squeeze(self._interpreter.get_tensor(output_index))
    return tensor

  def _postprocess(self, boxes: np.ndarray, classes: np.ndarray,
                   scores: np.ndarray, count: int, image_width: int,
                   image_height: int) -> List[Detection]:
    """Post-process the output of TFLite model into a list of Detection objects.
    Args:
        boxes: Bounding boxes of detected objects from the TFLite model.
        classes: Class index of the detected objects from the TFLite model.
        scores: Confidence scores of the detected objects from the TFLite model.
        count: Number of detected objects from the TFLite model.
        image_width: Width of the input image.
        image_height: Height of the input image.
    Returns:
        A list of Detection objects detected by the TFLite model.
    """
    results = []

    # Parse the model output into a list of Detection entities.
    for i in range(count):
      if scores[i] >= self._options.score_threshold:
        y_min, x_min, y_max, x_max = boxes[i]
        bounding_box = Rect(
            top=int(y_min * image_height),
            left=int(x_min * image_width),
            bottom=int(y_max * image_height),
            right=int(x_max * image_width))
        class_id = int(classes[i])
        category = Category(
            score=scores[i],
            label=self._label_list[class_id],  # 0 is reserved for background
            index=class_id)
        result = Detection(bounding_box=bounding_box, categories=[category])
        results.append(result)

    # Sort detection results by score ascending
    sorted_results = sorted(
        results,
        key=lambda detection: detection.categories[0].score,
        reverse=True)

    # Filter out detections in deny list
    filtered_results = sorted_results
    if self._options.label_deny_list is not None:
      filtered_results = list(
          filter(
              lambda detection: detection.categories[0].label not in self.
              _options.label_deny_list, filtered_results))

    # Keep only detections in allow list
    if self._options.label_allow_list is not None:
      filtered_results = list(
          filter(
              lambda detection: detection.categories[0].label in self._options.
              label_allow_list, filtered_results))

    # Only return maximum of max_results detection.
    if self._options.max_results > 0:
      result_count = min(len(filtered_results), self._options.max_results)
      filtered_results = filtered_results[:result_count]

    return filtered_results


_MARGIN = 10  # pixels
_ROW_SIZE = 10  # pixels
_FONT_SIZE = 1
_FONT_THICKNESS = 1
_TEXT_COLOR = (0, 0, 255)  # red


def visualize(
    image: np.ndarray,
    detections: List[Detection],
) -> np.ndarray:
  """Draws bounding boxes on the input image and return it.
  Args:
    image: The input RGB image.
    detections: The list of all "Detection" entities to be visualize.
  Returns:
    Image with bounding boxes.
  """
  for detection in detections:
    # Draw bounding_box
    start_point = detection.bounding_box.left, detection.bounding_box.top
    end_point = detection.bounding_box.right, detection.bounding_box.bottom
    cv2.rectangle(image, start_point, end_point, _TEXT_COLOR, 3)

    # Draw label and score
    category = detection.categories[0]
    class_name = category.label
    probability = round(category.score, 2)
    result_text = class_name + ' (' + str(probability) + ')'
    text_location = (_MARGIN + detection.bounding_box.left,
                     _MARGIN + _ROW_SIZE + detection.bounding_box.top)
    cv2.putText(image, result_text, text_location, cv2.FONT_HERSHEY_PLAIN,
                _FONT_SIZE, _TEXT_COLOR, _FONT_THICKNESS)

  return image

# %%
INPUT_IMAGE_URL = "https://storage.googleapis.com/cloud-ml-data/img/openimage/3/2520/3916261642_0a504acd60_o.jpg" #@param {type:"string"}
DETECTION_THRESHOLD = 0.3 #@param {type:"number"}

TEMP_FILE = '/tmp/image.png'

# !wget -q -O $TEMP_FILE $INPUT_IMAGE_URL
im = Image.open(TEMP_FILE)
im.thumbnail((512, 512), Image.ANTIALIAS)
image_np = np.asarray(im)

# Load the TFLite model
options = ObjectDetectorOptions(
      num_threads=4,
      score_threshold=DETECTION_THRESHOLD,
)
detector = ObjectDetector(model_path='model.tflite', options=options)

# Run object detection estimation using the model.
detections = detector.detect(image_np)

# Draw keypoints and edges on input image
image_np = visualize(image_np, detections)

# Show the detection result
Image.fromarray(image_np)
# Out:
# <PIL.Image.Image image mode=RGB size=384x512 at 0x7FA1BA019FD0>
